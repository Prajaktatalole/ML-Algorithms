# %% [markdown]
# ![image.png](attachment:423ad1f4-4178-41da-aea0-03c75eed1be6.png)

# %% [markdown]
# ![image.png](attachment:26446932-b47d-4f2d-b719-ef09c8aecde3.png)

# %%
We have to find correct k
k should be odd value only

# %% [markdown]
# ![image.png](attachment:89c67b0e-a2b7-4be0-acae-6fd78f473ed4.png)

# %% [markdown]
# ![image.png](attachment:ff7a758e-b65b-48c0-880a-223317364273.png)

# %%
###Elbow method is used to find optimum k value

# %% [markdown]
# ![image.png](attachment:6eae6aaa-23a4-4234-a2a1-a2589a636d96.png)

# %% [markdown]
# ![image.png](attachment:e6b243da-b589-4357-aa76-c8b18e3c1681.png)

# %% [markdown]
# ![image.png](attachment:0af1081a-13db-450b-bf95-8fe4739608a3.png)

# %%
## clinical sector dataset we can use KNN widely

# %% [markdown]
# ![image.png](attachment:a71d1214-2071-4425-9ea4-4b189661040c.png)

# %%
##  for p=1 we get L1 p=2 we get L2

# %%
#Outlier should be  treated or scaling should be done
